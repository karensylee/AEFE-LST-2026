# %% [markdown]
# # LST Model Analysis - Visualization Notebook
#
# This notebook generates all publication-ready figures from the analysis scripts.

# %%
# Setup: Add project root to path
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# %% [markdown]
# ## 1. Density Plots
# Generates hexbin density plots comparing predicted vs true LST for all models.

# %%
from analysis.density_plots import main as density_main
density_main()
# Out:
# Starting Density Plot Generation...
# Loading BLM...
# Loading BLAM...
# Loading BLAM-C...
# Loading CIM...
# Loading CIAM...
# Generating individual plots...
# Generating standard grid (2x4)...
# Generating 2x4 compact grid...
# Model: BLM, Condition: Clear-Sky, N: 2018219
# Model: BLAM, Condition: Clear-Sky, N: 2018219
# Model: CIM, Condition: Clear-Sky, N: 2018219
# Model: CIAM, Condition: Clear-Sky, N: 2018219
# Model: BLM, Condition: Cloudy-Sky, N: 2403261
# Model: BLAM, Condition: Cloudy-Sky, N: 2403261
# Model: CIM, Condition: Cloudy-Sky, N: 2403261
# Model: CIAM, Condition: Cloudy-Sky, N: 2403261
# Generating 2x2 All-Sky compact grid...
# Model: BLM, Condition: All-Sky, N: 4421480
# Model: BLAM, Condition: All-Sky, N: 4421480
# Model: CIM, Condition: All-Sky, N: 4421480
# Model: CIAM, Condition: All-Sky, N: 4421480
# Generating BLAM-C 1x2 compact grid...
# All tasks completed.

# %% [markdown]
# ## 2. Paired Dot Plots
# Station-level RMSE/STD comparisons with Wilcoxon signed-rank tests.

# %%
from analysis.paired_dot_plots import main as paired_dot_main
paired_dot_main()
# Out:
# Loading model data...
# Loaded models: ['BLM', 'BLAM', 'CIM', 'CIAM']
# Generating 2x4 compact paired dot panel...
# Saved: /home/ksylee/projects/lst/figures/statistical_tests/paired_dot_2x4_compact.jpg
# Generating individual metric plots...
# Saved: paired_dot_rmse.jpg
# Saved: paired_dot_std.jpg
#
# All paired dot plots generated.

# %%
from analysis.hourly_daily_rmse import main as hourly_daily_main
hourly_daily_main()
# Out:
# ...
# BLAM vs BLM: Hourly and Daily RMSE Comparison
# ...
# Output directory: /home/ksylee/projects/lst/figures/rmse_temporal
# Loading BLAM predictions from: /home/ksylee/projects/lst/models/xgb/BLAM/BLAM_ALL_predictions.csv
# Loaded 4,421,480 observations
# Date range (HST): 2024-01-01 to 2024-12-31
# Loading BLM predictions from: /home/ksylee/projects/lst/models/xgb/BLM/BLM_ALL_predictions.csv
# Loaded 4,421,480 observations
# Date range (HST): 2024-01-01 to 2024-12-31
#
# Generating hourly RMSE comparison box plot...
# Saved: /home/ksylee/projects/lst/figures/rmse_temporal/BLAM_vs_BLM_hourly_rmse_boxplot.jpg
#
# Generating daily RMSE comparison line plot...
# Saved: /home/ksylee/projects/lst/figures/rmse_temporal/BLAM_vs_BLM_daily_rmse_lineplot.jpg
#
# ...
# Analysis complete!
# Generated figures:
#   1. /home/ksylee/projects/lst/figures/rmse_temporal/BLAM_vs_BLM_hourly_rmse_boxplot.jpg
#   2. /home/ksylee/projects/lst/figures/rmse_temporal/BLAM_vs_BLM_daily_rmse_lineplot.jpg
# ...
